# %%
import pandas as pd

# %%
df = pd.read_csv("estudiantes.csv")

# %%
df.head()
# Out:
#    nombre  edad     carrera  calificacion       ciudad
# 0     Ana    20  Ingenieria            85         CDMX
# 1    Luis    22    Medicina            90  Guadalajara
# 2   María    21     Derecho            78         CDMX
# 3  Carlos    23  Ingenieria            92    Monterrey
# 4   Sofía    20    Medicina            88         CDMX

# %%
df.head(3)
# Out:
#   nombre  edad     carrera  calificacion       ciudad
# 0    Ana    20  Ingenieria            85         CDMX
# 1   Luis    22    Medicina            90  Guadalajara
# 2  María    21     Derecho            78         CDMX

# %%
df.dtypes
# Out:
# nombre          object
# edad             int64
# carrera         object
# calificacion     int64
# ciudad          object
# dtype: object

# %%
tipos_datos = df.dtypes

# %%
tipos_datos
# Out:
# nombre          object
# edad             int64
# carrera         object
# calificacion     int64
# ciudad          object
# dtype: object

# %%
df.select_dtypes(include="number")
# Out:
#    edad  calificacion
# 0    20            85
# 1    22            90
# 2    21            78
# 3    23            92
# 4    20            88
# 5    22            75

# %%
df.select_dtypes(include="object")
# Out:
#    nombre     carrera       ciudad
# 0     Ana  Ingenieria         CDMX
# 1    Luis    Medicina  Guadalajara
# 2   María     Derecho         CDMX
# 3  Carlos  Ingenieria    Monterrey
# 4   Sofía    Medicina         CDMX
# 5    Juan     Derecho       Puebla

# %%
lista_nombres = df["nombre"].tolist()

# %%
lista_nombres
# Out:
# ['Ana', 'Luis', 'María', 'Carlos', 'Sofía', 'Juan']

# %%
lista_ciudades = df["ciudad"].tolist()

# %%
lista_ciudades
# Out:
# ['CDMX', 'Guadalajara', 'CDMX', 'Monterrey', 'CDMX', 'Puebla']

# %%
lista_calificaciones = df["calificacion"].tolist()

# %%
lista_calificaciones
# Out:
# [85, 90, 78, 92, 88, 75]

# %%
lista_calificaciones[0] , lista_calificaciones[-1]
# Out:
# (85, 75)

# %%
diccionario_aprobatorio = {
    "promedio_aprobatorio":70
}

# %%
diccionario_aprobatorio
# Out:
# {'promedio_aprobatorio': 70}

# %%
diccionario_total = {
    "total_estudiantes":len(df)
}

# %%
diccionario_total
# Out:
# {'total_estudiantes': 6}

# %%
diccionario_carreras = {
    "carreras": df["carrera"].tolist()
}

# %%
diccionario_carreras
# Out:
# {'carreras': ['Ingenieria',
#   'Medicina',
#   'Derecho',
#   'Ingenieria',
#   'Medicina',
#   'Derecho']}

# %%
df["carrera"].value_counts()
# Out:
# carrera
# Ingenieria    2
# Medicina      2
# Derecho       2
# Name: count, dtype: int64

# %%
df["ciudad"].value_counts()
# Out:
# ciudad
# CDMX           3
# Guadalajara    1
# Monterrey      1
# Puebla         1
# Name: count, dtype: int64

# %%
df["carrera"].value_counts(normalize=True)
# Out:
# carrera
# Ingenieria    0.333333
# Medicina      0.333333
# Derecho       0.333333
# Name: proportion, dtype: float64

# %%
df["carrera"].value_counts(normalize=True)
# Out:
# carrera
# Ingenieria    0.333333
# Medicina      0.333333
# Derecho       0.333333
# Name: proportion, dtype: float64

# %%
df["carrera"].value_counts(normalize=True).sort_values(ascending=False)
# Out:
# carrera
# Ingenieria    0.333333
# Medicina      0.333333
# Derecho       0.333333
# Name: proportion, dtype: float64

# %%
df["calificacion"].min()
# Out:
# np.int64(75)

# %%
df["carrera"].nunique(), df["ciudad"].nunique()
# Out:
# (3, 4)
